# %% [markdown]
# <a href="https://colab.research.google.com/github/amartyaj/Python_Practice/blob/main/Jupyter/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re;
print("Hello World!!");
# Out:
# Hello World!!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Placement_Data.csv')

# %%
# df.head()
# df.info()
# df.shape
df['status'].value_counts()
df.describe().T
df.describe()
df['degree_t'].value_counts()
df['degree_p'][df['degree_t'] == 'Comm&Mgmt'].max()
df.describe()
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status
# 0     No     55.0         Mkt&HR  58.80      Placed
# 1    Yes     86.5        Mkt&Fin  66.28      Placed
# 2     No     75.0        Mkt&Fin  57.80      Placed
# 3     No     66.0         Mkt&HR  59.43  Not Placed
# 4     No     96.8        Mkt&Fin  55.50      Placed

# %%
sns.displot(df['etest_p'])

# %%
sns.countplot(x = 'hsc_s', data = df)
# Out:
# <Axes: xlabel='hsc_s', ylabel='count'>

# %%
sns.countplot(x = 'hsc_s', data = df, hue = 'status')
# Out:
# <Axes: xlabel='hsc_s', ylabel='count'>

# %%
df_heatmap = df[['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p']]
sns.heatmap(df_heatmap.corr(), annot = True)
# Out:
# <Axes: >

# %%
sns.boxplot(data = df, x = 'degree_p', y = 'hsc_s')
# Out:
# <Axes: xlabel='degree_p', ylabel='hsc_s'>

# %%
sns.lineplot(data = df, x = 'ssc_p', y = 'hsc_p', hue = 'status')
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_p'>

# %%
sns.histplot(data = df, x = 'degree_p', hue = 'status', kde = True)
# Out:
# <Axes: xlabel='degree_p', ylabel='Count'>

# %%
df.describe()
# df['ssc_p'][df['status'] == 'Placed'].describe()
df['ssc_p'][df['status'] == 'Not Placed'].describe()
# df['status']
# Out:
# count    67.000000
# mean     57.544030
# std       8.394246
# min      40.890000
# 25%      52.000000
# 50%      56.280000
# 75%      63.000000
# max      77.800000
# Name: ssc_p, dtype: float64

# %%
sns.jointplot(data = df, x = 'degree_p', y = 'ssc_p', kind = 'hex')

# %%
sns.histplot(data = df, x = 'etest_p', kde = True)
# df.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Titanic.csv')

# %%
# df2.shape
# df2.describe()
# df2.isna().sum().sum()
# df2.info()
# df2.drop(['Cabin'], axis = 1, inplace = True)
# df2.describe()
df2.isna().sum().sum()
# Out:
# 179

# %%
sns.scatterplot(data = df2, x = 'Age', y = 'Sex', hue = 'Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
sns.histplot(data = df2, x = 'Parch', kde = True)
# Out:
# <Axes: xlabel='Parch', ylabel='Count'>

# %%
sns.countplot(data = df2, x = 'Pclass', hue = 'Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
grouped_agg = df2.groupby('Pclass')['Survived'].agg(['mean', 'min', 'max', 'sum'])
print(grouped_agg)
df3 = df2['Pclass'][df2['Survived'] == 1]
df3.value_counts()
# df2['PassengedId'][df2['Survived'] == 1].groupby('Pclass')['PassengerId'].agg(['sum'])
# Out:
#             mean  min  max  sum
# Pclass
# 1       0.629630    0    1  136
# 2       0.472826    0    1   87
# 3       0.242363    0    1  119
# Pclass
# 1    136
# 3    119
# 2     87
# Name: count, dtype: int64

# %%
sns.countplot(data = df2, x = 'Embarked', hue = 'Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.boxplot(data = df2, x = 'Fare', y = 'Sex')
# Out:
# <Axes: xlabel='Fare', ylabel='Sex'>
